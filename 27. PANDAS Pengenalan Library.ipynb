# %% [markdown]
# **Materi ini berfokus pada bagaimana cara meng import dan eksport data**

# %%
pwd
# Out:
# 'C:\\Users\\HP\\1. BELAJAR PYTHON SEP'

# %%
import pandas as pd

# %%
pd.read_csv('kapal_titanic.csv') # ini hanya membaca tidak bisa mengedit
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
# jika ingin mengedit maka
dataku = pd.read_csv('kapal_titanic.csv')
dataku
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataku.head() # menunjukan 5 file paling awal
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
dataku.tail() # menunjukan 5 file paling akhir
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
dataku.to_csv('datacsv.csv', index=False) #False harus di sertakan untuk bisa memasukan tabel

# %%
pd.read_csv('datacsv.csv')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataku.to_excel('dataexcel.xlsx', index=False, sheet_name='Asik')

# %%
pd.read_excel('dataexcel.xlsx')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
# cara membaca html

datahtml = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %%
datahtml
# Out:
# [                         Bank NameBank       CityCity StateSt  CertCert  \
#  0             Heartland Tri-State Bank        Elkhart      KS     25851
#  1                  First Republic Bank  San Francisco      CA     59017
#  2                       Signature Bank       New York      NY     57053
#  3                  Silicon Valley Bank    Santa Clara      CA     24735
#  4                    Almena State Bank         Almena      KS     15426
#  ..                                 ...            ...     ...       ...
#  562                 Superior Bank, FSB       Hinsdale      IL     32646
#  563                Malta National Bank          Malta      OH      6629
#  564    First Alliance Bank & Trust Co.     Manchester      NH     34264
#  565  National State Bank of Metropolis     Metropolis      IL      3815
#  566                   Bank of Honolulu       Honolulu      HI     21029
#
#                   Acquiring InstitutionAI Closing DateClosing  FundFund
# ...

# %%
type(datahtml)
# Out:
# list

# %%
# cara membaca agar lebih gampang 

datahtml[0]
# Out:
#                          Bank NameBank       CityCity StateSt  CertCert  \
# 0             Heartland Tri-State Bank        Elkhart      KS     25851
# 1                  First Republic Bank  San Francisco      CA     59017
# 2                       Signature Bank       New York      NY     57053
# 3                  Silicon Valley Bank    Santa Clara      CA     24735
# 4                    Almena State Bank         Almena      KS     15426
# ..                                 ...            ...     ...       ...
# 562                 Superior Bank, FSB       Hinsdale      IL     32646
# 563                Malta National Bank          Malta      OH      6629
# 564    First Alliance Bank & Trust Co.     Manchester      NH     34264
# 565  National State Bank of Metropolis     Metropolis      IL      3815
# 566                   Bank of Honolulu       Honolulu      HI     21029
#
#                  Acquiring InstitutionAI Closing DateClosing  FundFund
# ...

# %%
# cara mengekspor data titanik ke bentuk sql (database)

from sqlalchemy import create_engine #create_engine adalah pandas akan menyiapkan memori di komputer selalu ada di sql

# %%
mesin = create_engine('sqlite:///:memory:')

# %%
dataku.to_sql('datasql', con=mesin)
# Out:
# 891

# %%
pd.read_sql('datasql', con=mesin)
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 2        2         1       3  female  26.0      0      0   7.9250        S
# 3        3         1       1  female  35.0      1      0  53.1000        S
# 4        4         0       3    male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 886    886         0       2    male  27.0      0      0  13.0000        S
# 887    887         1       1  female  19.0      0      0  30.0000        S
# 888    888         0       3  female   NaN      1      2  23.4500        S
# 889    889         1       1    male  26.0      0      0  30.0000        C
# 890    890         0       3    male  32.0      0      0   7.7500        Q
#
#      deck
# 0    None
# 1       C
# 2    None
# 3       C
# ...
