# %% [markdown]
# **LIBRARY YANG BISA DIGUNAKAN**
#
# * Matplotlitb
# * Seaborn
# * Plotly

# %%
import pandas as pd

# %%
dataku = pd.read_csv('kapal_titanic.csv')

# %%
dataku
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataku.age.hist()
# Out:
# <Axes: >

# %%
dataku['age'].hist(bins=30) #bins membuat batang lebih ramping
# Out:
# <Axes: >

# %%
dataku.age.plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# akan lebih bagus menggunakan

import seaborn as sns
sns.set()

# %%
dataku.age.plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
dataku.age.plot.hist(bins=30, alpha=0.4) # alpha adalah transparansi
# Out:
# <Axes: ylabel='Frequency'>

# %%
import numpy as np

# %%
np.random.seed(100)

# %%
angka = []
for i in range (0,100):
    angka.append(i)

# %%
baru = pd.DataFrame(np.random.rand(100,5), angka, ['A', 'B', 'C', 'D', 'E'])

# %%
baru
# Out:
#            A         B         C         D         E
# 0   0.051828  0.657822  0.136040  0.809162  0.266422
# 1   0.941333  0.382574  0.522291  0.181221  0.773876
# 2   0.795897  0.668867  0.119405  0.094007  0.927042
# 3   0.711092  0.923732  0.104019  0.722355  0.973529
# 4   0.715892  0.626694  0.381180  0.320553  0.860147
# ..       ...       ...       ...       ...       ...
# 95  0.501609  0.461435  0.219079  0.760057  0.760388
# 96  0.536131  0.367429  0.464601  0.692231  0.742875
# 97  0.807463  0.636301  0.325861  0.542471  0.618298
# 98  0.433287  0.300440  0.231476  0.606792  0.887554
# 99  0.280668  0.330867  0.864474  0.417446  0.628580
#
# [100 rows x 5 columns]

# %%
baru.plot.area() #kolom area luas permukaan
# Out:
# <Axes: >

# %%
baru.plot.area(alpha=0.4)
# Out:
# <Axes: >

# %%
baru2 = pd.DataFrame(np.random.rand(4,5), [0,1,2,3], ['A', 'B', 'C', 'D', 'E'])
baru2
# Out:
#           A         B         C         D         E
# 0  0.769493  0.630230  0.716141  0.619411  0.383885
# 1  0.223954  0.073736  0.425589  0.467817  0.470383
# 2  0.129372  0.753261  0.355458  0.467089  0.255471
# 3  0.947871  0.394397  0.009974  0.355138  0.555290

# %%
baru2.plot.bar(alpha=0.4)
# Out:
# <Axes: >

# %%
baru2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
baru2 ['C'].plot.bar()
# Out:
# <Axes: >

# %%
baru.plot.scatter(x='A', y='B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
baru.plot.scatter(x='A', y='B', c='E') # c disini adalah warna yang sesuai kolom E
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
baru.plot.scatter(x='A', y='B', c='E', cmap='ocean') #cmap membedakan berdasarkan warna
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# membedakan berdasarkan ukuran

baru.plot.scatter(x='A', y='B', s=baru.D)
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
baru.plot.scatter(x='A', y='B', s=baru.D*100)
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
baru.plot.scatter(x='A', y='B', s=baru.D*100, c='C', cmap='Reds')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
baru.plot.box() #melihat persentil
# Out:
# <Axes: >

# %%
baru.plot.line(y='B')
# Out:
# <Axes: >

# %%
baru.plot.line(y='B', lw=0.5 ) #menentukan tebal tipisnya garis
# Out:
# <Axes: >

# %%
baru.plot.line(y='B', lw=0.5, figsize=(10,5) ) #panjang lebarnya garis
# Out:
# <Axes: >

# %%
baru.plot.hexbin(x='A', y='B') #berbentuk heksagonal
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
baru.plot.hexbin(x='A', y='B', gridsize=20)
# Out:
# <Axes: xlabel='A', ylabel='B'>
